# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 144865 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.23-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.23-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.23-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import h5py
import numpy as np
from keras.utils import np_utils
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras import Sequential, Model
from tensorflow.keras.layers import Flatten, Dense, Dropout
import tqdm
import os
import cv2
from sklearn.svm import SVC

# %%
file = h5py.File('/content/drive/My Drive/695/dataset.hdf5',mode = 'r')

# %%
x_train = file['x_train'][:]
y_train = file['y_train'][:]

# %%
x_val = file['x_val'][:]
y_val = file['y_val'][:]

# %%
x_test = file['x_test'][:]
y_test = file['y_test'][:]

# %%
x_train = x_train.astype('float32')
x_val = x_val.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_val /= 255
x_test /= 255

# %%
vgg = VGG19(weights = 'imagenet', include_top = False, input_shape = (224, 224, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step

# %%
for layer in vgg.layers:
    layer.trainable = False

# %%
model = Sequential()
model.add(vgg)
model.add(Flatten())
model.add(Dense(512, activation = 'relu'))
model.add(Dropout(0.4))
model.add(Dense(1, activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Functional)           (None, 7, 7, 512)         20024384
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               12845568
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 32,870,465
# Trainable params: 12,846,081
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
checkpoint = ModelCheckpoint("/content/drive/My Drive/695/weights_cnnsvm.h5",monitor="val_accuracy",verbose=1,save_best_only=True,
                             save_weights_only=True)
earlystop = EarlyStopping(monitor="val_accuracy",patience=5,verbose=1)

# %%
history = model.fit(x_train,y_train, batch_size = 128, epochs = 100, validation_data=(x_val,y_val),shuffle = True,verbose=1,callbacks=[checkpoint,earlystop])
# Out:
# Epoch 1/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9924 - accuracy: 0.8280
# Epoch 00001: val_accuracy improved from -inf to 0.93719, saving model to /content/drive/My Drive/695/weights_cnnsvm.h5
# 51/51 [==============================] - 41s 803ms/step - loss: 0.9924 - accuracy: 0.8280 - val_loss: 0.1566 - val_accuracy: 0.9372
# Epoch 2/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1341 - accuracy: 0.9498
# Epoch 00002: val_accuracy improved from 0.93719 to 0.96182, saving model to /content/drive/My Drive/695/weights_cnnsvm.h5
# 51/51 [==============================] - 38s 741ms/step - loss: 0.1341 - accuracy: 0.9498 - val_loss: 0.1095 - val_accuracy: 0.9618
# Epoch 3/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1057 - accuracy: 0.9643
# Epoch 00003: val_accuracy did not improve from 0.96182
# 51/51 [==============================] - 38s 748ms/step - loss: 0.1057 - accuracy: 0.9643 - val_loss: 0.1014 - val_accuracy: 0.9612
# Epoch 4/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0935 - accuracy: 0.9655
# Epoch 00004: val_accuracy improved from 0.96182 to 0.96675, saving model to /content/drive/My Drive/695/weights_cnnsvm.h5
# 51/51 [==============================] - 38s 745ms/step - loss: 0.0935 - accuracy: 0.9655 - val_loss: 0.0901 - val_accuracy: 0.9667
# Epoch 5/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0787 - accuracy: 0.9718
# Epoch 00005: val_accuracy improved from 0.96675 to 0.96736, saving model to /content/drive/My Drive/695/weights_cnnsvm.h5
# 51/51 [==============================] - 39s 756ms/step - loss: 0.0787 - accuracy: 0.9718 - val_loss: 0.0853 - val_accuracy: 0.9674
# Epoch 6/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0717 - accuracy: 0.9749
# Epoch 00006: val_accuracy did not improve from 0.96736
# 51/51 [==============================] - 38s 741ms/step - loss: 0.0717 - accuracy: 0.9749 - val_loss: 0.0835 - val_accuracy: 0.9674
# Epoch 7/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0681 - accuracy: 0.9777
# Epoch 00007: val_accuracy did not improve from 0.96736
# 51/51 [==============================] - 38s 740ms/step - loss: 0.0681 - accuracy: 0.9777 - val_loss: 0.0911 - val_accuracy: 0.9674
# Epoch 8/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0639 - accuracy: 0.9771
# Epoch 00008: val_accuracy did not improve from 0.96736
# 51/51 [==============================] - 38s 739ms/step - loss: 0.0639 - accuracy: 0.9771 - val_loss: 0.1139 - val_accuracy: 0.9587
# Epoch 9/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0596 - accuracy: 0.9775
# Epoch 00009: val_accuracy improved from 0.96736 to 0.96921, saving model to /content/drive/My Drive/695/weights_cnnsvm.h5
# 51/51 [==============================] - 39s 760ms/step - loss: 0.0596 - accuracy: 0.9775 - val_loss: 0.0779 - val_accuracy: 0.9692
# Epoch 10/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0509 - accuracy: 0.9831
# Epoch 00010: val_accuracy improved from 0.96921 to 0.97229, saving model to /content/drive/My Drive/695/weights_cnnsvm.h5
# 51/51 [==============================] - 39s 756ms/step - loss: 0.0509 - accuracy: 0.9831 - val_loss: 0.0765 - val_accuracy: 0.9723
# Epoch 11/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0490 - accuracy: 0.9841
# Epoch 00011: val_accuracy improved from 0.97229 to 0.97475, saving model to /content/drive/My Drive/695/weights_cnnsvm.h5
# 51/51 [==============================] - 38s 752ms/step - loss: 0.0490 - accuracy: 0.9841 - val_loss: 0.0725 - val_accuracy: 0.9748
# Epoch 12/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0396 - accuracy: 0.9878
# Epoch 00012: val_accuracy did not improve from 0.97475
# 51/51 [==============================] - 38s 743ms/step - loss: 0.0396 - accuracy: 0.9878 - val_loss: 0.0734 - val_accuracy: 0.9723
# Epoch 13/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0447 - accuracy: 0.9848
# Epoch 00013: val_accuracy improved from 0.97475 to 0.97722, saving model to /content/drive/My Drive/695/weights_cnnsvm.h5
# 51/51 [==============================] - 39s 756ms/step - loss: 0.0447 - accuracy: 0.9848 - val_loss: 0.0703 - val_accuracy: 0.9772
# Epoch 14/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0384 - accuracy: 0.9878
# Epoch 00014: val_accuracy did not improve from 0.97722
# 51/51 [==============================] - 38s 740ms/step - loss: 0.0384 - accuracy: 0.9878 - val_loss: 0.0906 - val_accuracy: 0.9667
# Epoch 15/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0383 - accuracy: 0.9872
# Epoch 00015: val_accuracy did not improve from 0.97722
# 51/51 [==============================] - 38s 740ms/step - loss: 0.0383 - accuracy: 0.9872 - val_loss: 0.0742 - val_accuracy: 0.9698
# Epoch 16/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0316 - accuracy: 0.9900
# Epoch 00016: val_accuracy improved from 0.97722 to 0.97845, saving model to /content/drive/My Drive/695/weights_cnnsvm.h5
# 51/51 [==============================] - 39s 760ms/step - loss: 0.0316 - accuracy: 0.9900 - val_loss: 0.0675 - val_accuracy: 0.9784
# Epoch 17/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0276 - accuracy: 0.9906
# Epoch 00017: val_accuracy did not improve from 0.97845
# 51/51 [==============================] - 38s 736ms/step - loss: 0.0276 - accuracy: 0.9906 - val_loss: 0.0687 - val_accuracy: 0.9778
# Epoch 18/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0321 - accuracy: 0.9891
# Epoch 00018: val_accuracy did not improve from 0.97845
# 51/51 [==============================] - 38s 743ms/step - loss: 0.0321 - accuracy: 0.9891 - val_loss: 0.0704 - val_accuracy: 0.9754
# Epoch 19/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0257 - accuracy: 0.9921
# Epoch 00019: val_accuracy did not improve from 0.97845
# 51/51 [==============================] - 38s 740ms/step - loss: 0.0257 - accuracy: 0.9921 - val_loss: 0.0885 - val_accuracy: 0.9667
# Epoch 20/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0241 - accuracy: 0.9918
# Epoch 00020: val_accuracy did not improve from 0.97845
# 51/51 [==============================] - 38s 743ms/step - loss: 0.0241 - accuracy: 0.9918 - val_loss: 0.0797 - val_accuracy: 0.9692
# Epoch 21/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 0.9935
# Epoch 00021: val_accuracy did not improve from 0.97845
# 51/51 [==============================] - 38s 739ms/step - loss: 0.0213 - accuracy: 0.9935 - val_loss: 0.0712 - val_accuracy: 0.9748
# Epoch 00021: early stopping

# %%
model.load_weights('/content/drive/My Drive/695/weights_cnnsvm.h5')

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")
fig = plt.figure(figsize=(12,6))
epochs = range(1,len(history.history['accuracy'])+1)
plt.subplot(1,2,1)
plt.plot(epochs,history.history["accuracy"],"go-")
plt.plot(epochs,history.history["val_accuracy"],"ro-")
plt.title("Model Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Train","val"],loc = "upper left")

plt.subplot(1,2,2)
plt.plot(epochs,history.history["loss"],"go-")
plt.plot(epochs,history.history["val_loss"],"ro-")
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Train","val"],loc = "upper left")
plt.show()

# %%
model_feat = Model(inputs=model.input,outputs=model.get_layer('dense').output)
model_feat.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19_input (InputLayer)     [(None, 224, 224, 3)]     0
# _________________________________________________________________
# vgg19 (Functional)           (None, 7, 7, 512)         20024384
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               12845568
# =================================================================
# Total params: 32,869,952
# Trainable params: 12,845,568
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
feat_train = model_feat.predict(x_train)
print(feat_train.shape)
feat_val = model_feat.predict(x_val)
print(feat_val.shape)
feat_test = model_feat.predict(x_test)
print(feat_test.shape)
# Out:
# (6495, 512)
# (1624, 512)
# (903, 512)

# %%
svm = SVC(kernel='rbf')
svm.fit(feat_train,y_train)
print('fitting done !!!')
# Out:
# fitting done !!!

# %%
svm.score(feat_train,y_train)
# Out:
# 0.9967667436489608

# %%
svm.score(feat_val,y_val)
# Out:
# 0.9729064039408867

# %%
svm.score(feat_test,y_test)
# Out:
# 0.9723145071982281
